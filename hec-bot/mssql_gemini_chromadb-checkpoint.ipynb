# %% [markdown]
# # Generating SQL for Microsoft SQL Server using Google Gemini, ChromaDB
# This notebook runs through the process of using the `vanna` Python package to generate SQL using AI (RAG + LLMs) including connecting to a database and training.

# %% [markdown]
# ## Setup

# %%
pip install vanna[chromadb,gemini]
# Out:
# Requirement already satisfied: vanna[chromadb,gemini] in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (0.7.9)
# Requirement already satisfied: requests in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (2.32.4)
# Requirement already satisfied: tabulate in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (0.9.0)
# Requirement already satisfied: plotly in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (6.1.2)
# Requirement already satisfied: pandas in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (2.3.0)
# Requirement already satisfied: sqlparse in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (0.5.3)
# Requirement already satisfied: kaleido in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (0.2.1)
# Requirement already satisfied: flask in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (3.1.1)
# Requirement already satisfied: flask-sock in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (0.7.0)
# Requirement already satisfied: flasgger in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (0.9.7.1)
# Requirement already satisfied: sqlalchemy in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (2.0.41)
# Requirement already satisfied: chromadb<1.0.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (0.6.3)
# Requirement already satisfied: google-generativeai in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from vanna[chromadb,gemini]) (0.8.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (2.11.7)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.115.12)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (2.3.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (4.10.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.55b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (9.1.2)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (14.0.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (24.2)
# Requirement already satisfied: pyproject_hooks in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (1.2.0)
# Requirement already satisfied: colorama in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (0.4.6)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (0.46.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,gemini]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,gemini]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,gemini]) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (1.3.1)
# Requirement already satisfied: certifi in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.16.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.4.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (5.29.5)
# Requirement already satisfied: sympy in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from posthog>=2.4.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from posthog>=2.4.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from requests->vanna[chromadb,gemini]) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,gemini]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,gemini]) (0.33.0)
# Requirement already satisfied: filelock in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,gemini]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,gemini]) (2025.5.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.9.0->chromadb<1.0.0->vanna[chromadb,gemini]) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.9.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (3.5.4)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from flasgger->vanna[chromadb,gemini]) (4.24.0)
# Requirement already satisfied: mistune in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from flasgger->vanna[chromadb,gemini]) (3.1.3)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from flask->vanna[chromadb,gemini]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from flask->vanna[chromadb,gemini]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from flask->vanna[chromadb,gemini]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from flask->vanna[chromadb,gemini]) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from flask->vanna[chromadb,gemini]) (3.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (0.25.1)
# Requirement already satisfied: simple-websocket>=0.5.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from flask-sock->vanna[chromadb,gemini]) (1.1.0)
# Requirement already satisfied: wsproto in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from simple-websocket>=0.5.1->flask-sock->vanna[chromadb,gemini]) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai->vanna[chromadb,gemini]) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai->vanna[chromadb,gemini]) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai->vanna[chromadb,gemini]) (2.172.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai->vanna[chromadb,gemini]) (1.26.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->vanna[chromadb,gemini]) (1.71.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from pandas->vanna[chromadb,gemini]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from pandas->vanna[chromadb,gemini]) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from plotly->vanna[chromadb,gemini]) (1.42.1)
# Requirement already satisfied: greenlet>=1 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy->vanna[chromadb,gemini]) (3.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\fauzi.hec\appdata\local\programs\python\python313\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from vanna.chromadb import ChromaDB_VectorStore
from vanna.google import GoogleGeminiChat

# %%
class MyVanna(ChromaDB_VectorStore, GoogleGeminiChat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        GoogleGeminiChat.__init__(self, config={'api_key': '', 'model': 'models/gemini-2.5-flash'}) # type: ignore

vn = MyVanna()

# %%
vn.connect_to_mssql(odbc_conn_str=r'DRIVER={ODBC Driver 17 for SQL Server};SERVER=;DATABASE=;UID=;PWD=')

# %% [markdown]
# ## Training
# You only need to train once. Do not train again unless you want to add more training data.

# %%
# The information schema query may need some tweaking depending on your database. This is a good starting point.
df_information_schema = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS")

# This will break up the information schema into bite-sized chunks that can be referenced by the LLM
plan = vn.get_training_plan_generic(df_information_schema)
plan

# If you like the plan, then uncomment this and run it to train
# vn.train(plan=plan)
# Out:
# Train on Information Schema: BISM_20250731.dbo EVENTTYPES
# Train on Information Schema: BISM_20250731.dbo CUSTOMERS
# Train on Information Schema: BISM_20250731.dbo AERCUSTOMERSERVICEERRORS
# Train on Information Schema: BISM_20250731.dbo ARTICLES
# Train on Information Schema: BISM_20250731.dbo V_TRANSACTIONS_DATA
# Train on Information Schema: BISM_20250731.dbo V_IMPORTEXPORTTEMPLATES_ARTICLES
# Train on Information Schema: BISM_20250731.dbo DEVICESETUPS
# Train on Information Schema: BISM_20250731.dbo DESKTOPALERTS
# Train on Information Schema: BISM_20250731.dbo TANKFLOWRATES
# Train on Information Schema: BISM_20250731.dbo AERDISPENSERTOTALIZERS
# Train on Information Schema: BISM_20250731.dbo PRODUCTGROUPS
# Train on Information Schema: BISM_20250731.dbo TERMINALTYPES
# Train on Information Schema: BISM_20250731.dbo EMPLOYEEGROUPS
# Train on Information Schema: BISM_20250731.dbo POLLINGSEQUENCES
# Train on Information Schema: BISM_20250731.dbo TANKSTATICLEAKS
# Train on Information Schema: BISM_20250731.dbo CARDAUTHORIZATIONKEYS
# Train on Information Schema: BISM_20250731.dbo PRODUCTS
# Train on Information Schema: BISM_20250731.dbo AERPRODUCTSALES
# Train on Information Schema: BISM_20250731.dbo ASSIGNMENTLISTTYPES
# Train on Information Schema: BISM_20250731.dbo TERMINALTYPEDEVICETYPEASSIGNMENT
# Train on Information Schema: BISM_20250731.dbo EMPLOYEES
# Train on Information Schema: BISM_20250731.dbo DBCLEARCONFIGS
# Train on Information Schema: BISM_20250731.dbo FUELINGEVENTS
# Train on Information Schema: BISM_20250731.dbo CARDS
# Train on Information Schema: BISM_20250731.dbo PRODUCTARTICLES
# Train on Information Schema: BISM_20250731.dbo ASSIGNMENTLISTROOTS
# Train on Information Schema: BISM_20250731.dbo TERMINALS
# Train on Information Schema: BISM_20250731.dbo AERWISHPINS
# Train on Information Schema: BISM_20250731.dbo VEHICLEGROUPS
# Train on Information Schema: BISM_20250731.dbo TANKTABLES
# Train on Information Schema: BISM_20250731.dbo TANKGROUPS
# Train on Information Schema: BISM_20250731.dbo ASSIGNMENTLISTS
# Train on Information Schema: BISM_20250731.dbo V_WEB_USERS
# Train on Information Schema: BISM_20250731.dbo V_TRANSACTIONS
# Train on Information Schema: BISM_20250731.dbo USERS
# Train on Information Schema: BISM_20250731.dbo V_CARDS
# Train on Information Schema: BISM_20250731.dbo V_CUSTOMERS
# Train on Information Schema: BISM_20250731.dbo VEHICLES
# Train on Information Schema: BISM_20250731.dbo ADDITIONALDATAS
# Train on Information Schema: BISM_20250731.dbo V_IMPORTEXPORTTEMPLATES_STATIONS
# Train on Information Schema: BISM_20250731.dbo V_CONTRACTS
# Train on Information Schema: BISM_20250731.dbo V_DRIVERS
# Train on Information Schema: BISM_20250731.dbo OLDTANKTABLES
# Train on Information Schema: BISM_20250731.dbo V_VEHICLES
# Train on Information Schema: BISM_20250731.dbo V_TERMINALS
# Train on Information Schema: BISM_20250731.dbo TRANSACTIONS
# Train on Information Schema: BISM_20250731.dbo V_FLEETNETS
# Train on Information Schema: BISM_20250731.dbo FLEETIMPORT
# Train on Information Schema: BISM_20250731.dbo TANKS
# Train on Information Schema: BISM_20250731.dbo MAPPINGS
# Train on Information Schema: BISM_20250731.dbo TANKQUIETPERIODS
# Train on Information Schema: BISM_20250731.dbo V_CONTRACT_PRODUCTS
# Train on Information Schema: BISM_20250731.dbo SECURITYPERMISSIONITEMS
# Train on Information Schema: BISM_20250731.dbo SETUPS
# Train on Information Schema: BISM_20250731.dbo V_CONTRACT_STATIONS
# Train on Information Schema: BISM_20250731.dbo FLEETIMPORTMAPPING
# Train on Information Schema: BISM_20250731.dbo V_CONTRACT_FLEETNETS
# Train on Information Schema: BISM_20250731.dbo PERIODTYPES
# Train on Information Schema: BISM_20250731.dbo V_CONTRACT_ARTICLES
# Train on Information Schema: BISM_20250731.dbo V_FLEETNET_STATION
# Train on Information Schema: BISM_20250731.dbo ACTIONREQUESTLIST
# Train on Information Schema: BISM_20250731.dbo V_FLEETNET_MANDATOR
# Train on Information Schema: BISM_20250731.dbo TERMINALPARAMSHECSTAR
# Train on Information Schema: BISM_20250731.dbo TANKDYNAMICLEAKS
# Train on Information Schema: BISM_20250731.dbo SECURITYPERMISSIONS
# Train on Information Schema: BISM_20250731.dbo AUDITS
# Train on Information Schema: BISM_20250731.dbo V_IMPORTFILES
# Train on Information Schema: BISM_20250731.dbo V_EXPORTFILES
# Train on Information Schema: BISM_20250731.dbo V_EXPORTJOBS
# Train on Information Schema: BISM_20250731.dbo V_DBINFO_TABLECOLUMNS
# Train on Information Schema: BISM_20250731.dbo V_STATION_TERMINALS
# Train on Information Schema: BISM_20250731.dbo TANKGROUPDELIVERIES
# Train on Information Schema: BISM_20250731.dbo V_ASSIGNMENTLISTS
# Train on Information Schema: BISM_20250731.dbo ONLINEBATCHES
# Train on Information Schema: BISM_20250731.dbo SECURITYGROUPS
# Train on Information Schema: BISM_20250731.dbo CONFIGGROUPS
# Train on Information Schema: BISM_20250731.dbo V_FLEETNET_MANDATOR_ARTICLES
# Train on Information Schema: BISM_20250731.dbo V_AERGROUP_ITEMS
# Train on Information Schema: BISM_20250731.dbo CONTRACTS
# Train on Information Schema: BISM_20250731.dbo V_FLEETNET_MANDATOR_USERS
# Train on Information Schema: BISM_20250731.dbo V_AERGROUP_EMPLOYEES
# Train on Information Schema: BISM_20250731.dbo METERMAPPINGS
# Train on Information Schema: BISM_20250731.dbo V_FLEETNET_STATION_USERS
# Train on Information Schema: BISM_20250731.dbo V_AERGROUP_STATIONS
# Train on Information Schema: BISM_20250731.dbo V_FLEETNET_STATION_TERMINALS
# Train on Information Schema: BISM_20250731.dbo SECURITYGROUPMEMBERS
# Train on Information Schema: BISM_20250731.dbo GLOBALPARAMS
# Train on Information Schema: BISM_20250731.dbo TANKGROUPDATAS
# Train on Information Schema: BISM_20250731.dbo V_CONTRACT_RESTRICTCLASS
# Train on Information Schema: BISM_20250731.dbo FLEETNETS
# Train on Information Schema: BISM_20250731.dbo V_RESTRICTCLASSES
# Train on Information Schema: BISM_20250731.dbo ONLINEAUTHORIZATIONS
# Train on Information Schema: BISM_20250731.dbo EVENTS
# Train on Information Schema: BISM_20250731.dbo AUDITTBLCHANGES
# Train on Information Schema: BISM_20250731.dbo AUDITTBLCHANGESCONFIG
# Train on Information Schema: BISM_20250731.dbo AUTOMATICMETERMAPPINGS
# Train on Information Schema: BISM_20250731.dbo PARAMDOMAINS
# Train on Information Schema: BISM_20250731.dbo TANKGROUPLIMITS
# Train on Information Schema: BISM_20250731.dbo trans_date_time
# Train on Information Schema: BISM_20250731.dbo SECURITYGROUPACCESS
# Train on Information Schema: BISM_20250731.dbo decant
# Train on Information Schema: BISM_20250731.dbo tp_bar
# Train on Information Schema: BISM_20250731.dbo STATIONGROUPS
# Train on Information Schema: BISM_20250731.dbo fuel_issued
# Train on Information Schema: BISM_20250731.dbo AUTOMATICMETERMAPPINGSTATUSES
# Train on Information Schema: BISM_20250731.dbo stocks
# Train on Information Schema: BISM_20250731.dbo MONITORGROUPS
# Train on Information Schema: BISM_20250731.dbo SECURITYUSERACCESS
# Train on Information Schema: BISM_20250731.dbo STATIONS
# Train on Information Schema: BISM_20250731.dbo ONLINEAUTHORIZATIONARTICLES
# Train on Information Schema: BISM_20250731.dbo PAYMENTS
# Train on Information Schema: BISM_20250731.dbo AUTOCALIBRATIONENTRIES
# Train on Information Schema: BISM_20250731.dbo MONITORGROUPSDETAILS
# Train on Information Schema: BISM_20250731.dbo B_TRANSACTIONS
# Train on Information Schema: BISM_20250731.dbo B_STOCKS
# Train on Information Schema: BISM_20250731.dbo CARDTYPES
# Train on Information Schema: BISM_20250731.dbo MANDATORS
# Train on Information Schema: BISM_20250731.dbo AUTOCALIBRATIONCONFIGS
# Train on Information Schema: BISM_20250731.dbo IMPORTFILES
# Train on Information Schema: BISM_20250731.dbo LANGUAGES
# Train on Information Schema: BISM_20250731.dbo TANKGROUPFLOWRATES
# Train on Information Schema: BISM_20250731.dbo CARDSYSTEMTYPES
# Train on Information Schema: BISM_20250731.dbo fuelratio
# Train on Information Schema: BISM_20250731.dbo TERMINALPARAMSHECSTAR2
# Train on Information Schema: BISM_20250731.dbo categorywisefuelissued
# Train on Information Schema: BISM_20250731.dbo COUNTRIES
# Train on Information Schema: BISM_20250731.dbo SCHEDULERJOBS
# Train on Information Schema: BISM_20250731.dbo TANKGROUPSTATICLEAKS
# Train on Information Schema: BISM_20250731.dbo CARDAUTHORIZATIONPINTYPES
# Train on Information Schema: BISM_20250731.dbo EXPORTFILES
# Train on Information Schema: BISM_20250731.dbo TERMINALPARAMSTA2331
# Train on Information Schema: BISM_20250731.dbo CURRENCIES
# Train on Information Schema: BISM_20250731.dbo CARDLAYOUTS
# Train on Information Schema: BISM_20250731.dbo MANDATOR_USERS
# Train on Information Schema: BISM_20250731.dbo DATABASEMAINTENANCEHISTORY
# Train on Information Schema: BISM_20250731.dbo FLEETIMPORTFORMATS
# Train on Information Schema: BISM_20250731.dbo TANKGROUPQUIETPERIODS
# Train on Information Schema: BISM_20250731.dbo TAXREFUNDS
# Train on Information Schema: BISM_20250731.dbo TERMINALSETTINGSTA2331
# Train on Information Schema: BISM_20250731.dbo TRANSLATIONPREDEFINEDVALUES
# Train on Information Schema: BISM_20250731.dbo AERGROUPS
# Train on Information Schema: BISM_20250731.dbo IMPORTEXPORTFORMATS
# Train on Information Schema: BISM_20250731.dbo TANKGROUPDYNAMICLEAKS
# Train on Information Schema: BISM_20250731.dbo ARTICLEPRICES
# Train on Information Schema: BISM_20250731.dbo CURRENCYEXCHANGERATES
# Train on Information Schema: BISM_20250731.dbo PUMPSTATUSES
# Train on Information Schema: BISM_20250731.dbo AERGROUPITEMS
# Train on Information Schema: BISM_20250731.dbo CARDLAYOUTSETTINGS
# Train on Information Schema: BISM_20250731.dbo ARTICLEPRICEACTIVATIONS
# Train on Information Schema: BISM_20250731.dbo AERHISTORY
# Train on Information Schema: BISM_20250731.dbo QUANTITYUNITS
# Train on Information Schema: BISM_20250731.dbo TANKDATAS
# Train on Information Schema: BISM_20250731.dbo DEVICESSTATES
# Train on Information Schema: BISM_20250731.dbo IMPORTEXPORTFORMATTABLES
# Train on Information Schema: BISM_20250731.dbo CONSUMPTIONUNITS
# Train on Information Schema: BISM_20250731.dbo REPORTTEMPLATES
# Train on Information Schema: BISM_20250731.dbo AERWETSTOCKRESULTS
# Train on Information Schema: BISM_20250731.dbo TANKDELIVERIES
# Train on Information Schema: BISM_20250731.dbo IMPORTEXPORTFORMATTABLEFIELDS
# Train on Information Schema: BISM_20250731.dbo IMPORTEXPORTTEMPLATES
# Train on Information Schema: BISM_20250731.dbo SALUTATIONS
# Train on Information Schema: BISM_20250731.dbo REPORTTEMPLATEFILEDS
# Train on Information Schema: BISM_20250731.dbo SCHEDULERJOBTIMETABLES
# Train on Information Schema: BISM_20250731.dbo SCHEDULERINTERNALJOBS
# Train on Information Schema: BISM_20250731.dbo DEVICESHISTORY
# Train on Information Schema: BISM_20250731.dbo DATATRANSFERTEMPLATES
# Train on Information Schema: BISM_20250731.dbo COSTCENTERS
# Train on Information Schema: BISM_20250731.dbo AERWETSTOCKDELIVERIES
# Train on Information Schema: BISM_20250731.dbo TOTALIZERCOUNTERS
# Train on Information Schema: BISM_20250731.dbo DEVICETYPES
# Train on Information Schema: BISM_20250731.dbo TANKLIMITS
# Train on Information Schema: BISM_20250731.dbo TAXKEYS
# Train on Information Schema: BISM_20250731.dbo DEVICES
# Train on Information Schema: BISM_20250731.dbo CUSTOMERGROUPS
# Train on Information Schema: BISM_20250731.dbo AERPRODUCTSUMMARIES
# Train on Information Schema: BISM_20250731.dbo ATMODEMS
# Train on Information Schema: BISM_20250731.dbo V_IMPORTEXPORTTEMPLATES_CARDLAYOUTS
# Train on Information Schema: BISM_20250731.dbo ARTICLEGROUPS
# Train on Information Schema: BISM_20250731.dbo DATATRANSFERTEMPLATEDETAILS

# %%
# The following are methods for adding training data. Make sure you modify the examples to match your database.

# DDL statements are powerful because they specify table names, colume names, types, and potentially relationships
vn.train(ddl="""
CREATE TABLE B_TRANSACTIONS (
    ID_Transactions INT,
    DateTime DATETIME,
    Terminal NVARCHAR(108),
    Card NVARCHAR(40),
    Quantity FLOAT,
    Customer NVARCHAR(100),
    VehicleNumber NVARCHAR(30),
    VehicleLicensePlate NVARCHAR(20),
    Mileage INT,
    AdditionalEntry NVARCHAR(20)
);

CREATE TABLE B_STOCKS (
    DateTime DATETIME,
    Opening FLOAT,
    Inflow FLOAT,
    [PT BAR] FLOAT,
    Dispensed FLOAT,
    Closing FLOAT
);
""")

# Sometimes you may want to add documentation about your business terminology or definitions.
vn.train(documentation="""
The B_TRANSACTIONS table records fuel refueling activities by operational vehicles.
ID_Transactions: Unique identifier for each transaction.
DateTime: Date and time of the fuel transaction.
Terminal: Code of the fuel dispensing terminal/pump (e.g., FT-02, FM-01).
Card: RFID card number used to identify the vehicle (optional).
Quantity: Amount of fuel dispensed, in liters.
Customer: Name of the company or fuel consumer unit (e.g., PT BAR).
VehicleNumber: Internal vehicle/unit code (e.g., GS-45-46).
VehicleLicensePlate: Official license plate or vehicle tag.
Mileage: Odometer reading or hourmeter value at refueling time.
AdditionalEntry: Backup field for vehicle info if RFID is not used.

The B_STOCKS table records daily fuel stock levels and movements.
DateTime: Date and time of the stock record.
Opening: Fuel stock at the start of the day.
Inflow: Total amount of fuel received (e.g., unloading from tanker).
PT BAR: Fuel issued specifically to customer PT BAR.
Dispensed: Total fuel dispensed from terminals FT-02, FT-03, and FT-04 only.
Closing: Remaining stock at the end of the day.
""")


# You can also add SQL queries to your training data. This is useful if you have some queries already laying around. You can just copy and paste those from your editor to begin generating new SQL.
vn.train(sql="""
-- 1. Show latest 10 transactions
SELECT TOP 10 * FROM B_TRANSACTIONS ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 2. Total quantity per terminal for the current month
SELECT 
    Terminal, 
    SUM(Quantity) AS Total 
FROM B_TRANSACTIONS 
WHERE 
    DateTime >= DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1)
    AND DateTime < DATEADD(MONTH, 1, DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1))
GROUP BY Terminal;
""")

vn.train(sql="""
-- 3. Total transactions by customer for the current month
SELECT Customer, COUNT(*) AS TotalTransactions 
FROM B_TRANSACTIONS 
WHERE 
    DateTime >= DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1)
    AND DateTime < DATEADD(MONTH, 1, DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1))
GROUP BY Customer;
""")

vn.train(sql="""
-- 4. Total dispensed from FT-02, FT-03, FT-04
SELECT Terminal, SUM(Quantity) FROM B_TRANSACTIONS WHERE Terminal IN ('FT-02','FT-03','FT-04') GROUP BY Terminal;
""")

vn.train(sql="""
-- 5. Fuel issued to PT BAR
SELECT SUM(Quantity) AS TotalPTBAR FROM B_TRANSACTIONS WHERE Customer LIKE '%PT BAR%';
""")

vn.train(sql="""
-- 6. Mileage summary per vehicle
SELECT 
    t.VehicleNumber,
    t.Mileage AS LatestMileage,
    t.DateTime AS LatestMileageDate
FROM B_TRANSACTIONS t
INNER JOIN (
    SELECT 
        VehicleNumber,
        MAX(Mileage) AS MaxMileage
    FROM B_TRANSACTIONS
    WHERE Mileage IS NOT NULL
    GROUP BY VehicleNumber
) m ON t.VehicleNumber = m.VehicleNumber AND t.Mileage = m.MaxMileage
WHERE t.Mileage IS NOT NULL;
""")

vn.train(sql="""
-- 7. Daily stock summary for the current month
SELECT * 
FROM B_STOCKS
WHERE 
    DateTime >= DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1)
    AND DateTime < DATEADD(MONTH, 1, DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1))
ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 8. Show days with fuel inflow or unloading
SELECT DateTime, Inflow FROM B_STOCKS WHERE Inflow > 0;
""")

vn.train(sql="""
-- 9. Show days with high dispensed volume
SELECT DateTime, Dispensed FROM B_STOCKS WHERE Dispensed > 1000 ORDER BY Dispensed DESC;
""")

vn.train(sql="""
-- 10. Closing stock per day for the current month
SELECT DateTime, Closing FROM B_STOCKS WHERE 
    DateTime >= DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1)
    AND DateTime < DATEADD(MONTH, 1, DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1))
ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 11. PT BAR daily usage
SELECT DateTime, [PT BAR] FROM B_STOCKS WHERE [PT BAR] > 0 ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 12. Vehicle refueling count
SELECT 
    VehicleNumber, 
    COUNT(*) AS Refuels 
FROM B_TRANSACTIONS 
WHERE 
    VehicleNumber IS NOT NULL AND 
    LTRIM(RTRIM(VehicleNumber)) <> ''
GROUP BY VehicleNumber 
ORDER BY Refuels DESC;
""")

vn.train(sql="""
-- 13. Daily total issued
SELECT 
    DateTime AS TransDate,
    [PT BAR] + Dispensed AS TotalIssued
FROM B_STOCKS
WHERE 
    DateTime >= DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1)
    AND DateTime < DATEADD(MONTH, 1, DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1))
    AND ([PT BAR] IS NOT NULL OR Dispensed IS NOT NULL)
ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 14. Card usage summary
SELECT Card, COUNT(*) AS Uses FROM B_TRANSACTIONS WHERE Card IS NOT NULL GROUP BY Card;
""")

vn.train(sql="""
-- 15. Show transactions without card
SELECT * FROM B_TRANSACTIONS WHERE Card IS NULL;
""")

vn.train(sql="""
-- 16. Total quantity per terminal per day (this month only)
SELECT 
    CAST(DateTime AS DATE) AS TransDate,
    Terminal, 
    SUM(Quantity) AS TotalQty
FROM B_TRANSACTIONS
WHERE 
    DateTime >= DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1)
    AND DateTime < DATEADD(MONTH, 1, DATEFROMPARTS(YEAR(GETDATE()), MONTH(GETDATE()), 1))
GROUP BY 
    CAST(DateTime AS DATE), 
    Terminal
ORDER BY 
    TransDate DESC, 
    Terminal;
""")

vn.train(sql="""
-- 17. Vehicle refueling volume
SELECT VehicleNumber, SUM(Quantity) AS Total FROM B_TRANSACTIONS GROUP BY VehicleNumber;
""")

vn.train(sql="""
-- 18. Top 5 terminals by volume
SELECT TOP 5 Terminal, SUM(Quantity) AS Total FROM B_TRANSACTIONS GROUP BY Terminal ORDER BY Total DESC;
""")

vn.train(sql="""
-- 19. Terminal usage frequency
SELECT Terminal, COUNT(*) AS Frequency FROM B_TRANSACTIONS GROUP BY Terminal ORDER BY Frequency DESC;
""")

vn.train(sql="""
-- 20. Inflow vs dispensed comparison
SELECT DateTime, Inflow, Dispensed FROM B_STOCKS ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 21. Fuel received and opening stock
SELECT DateTime, Opening, Inflow FROM B_STOCKS ORDER BY DateTime;
""")

vn.train(sql="""
-- 22. Daily net change in stock
SELECT DateTime, (Opening + Inflow - Dispensed) AS NetStock FROM B_STOCKS;
""")

vn.train(sql="""
-- 23. Vehicles without license plate
SELECT * FROM B_TRANSACTIONS WHERE VehicleLicensePlate IS NULL;
""")

vn.train(sql="""
-- 24. Show transactions by FT-02 only
SELECT * FROM B_TRANSACTIONS WHERE Terminal = 'FT-02';
""")

vn.train(sql="""
-- 25. Total quantity by license plate
SELECT VehicleLicensePlate, SUM(Quantity) AS Total FROM B_TRANSACTIONS GROUP BY VehicleLicensePlate;
""")

vn.train(sql="""
-- 26. Average dispensed by day
SELECT CAST(DateTime AS DATE) AS Day, AVG(Quantity) AS AvgQty FROM B_TRANSACTIONS GROUP BY CAST(DateTime AS DATE);
""")

vn.train(sql="""
-- 27. Quantity trend for PT BAR
SELECT DateTime, Quantity FROM B_TRANSACTIONS WHERE Customer LIKE '%PT BAR%' ORDER BY DateTime;
""")

vn.train(sql="""
-- 28. Top customers by fuel usage
SELECT TOP 10 Customer, SUM(Quantity) AS Total FROM B_TRANSACTIONS GROUP BY Customer ORDER BY Total DESC;
""")

vn.train(sql="""
-- 29. Count of refueling per day
SELECT CAST(DateTime AS DATE) AS Day, COUNT(*) AS Refuels FROM B_TRANSACTIONS GROUP BY CAST(DateTime AS DATE);
""")

vn.train(sql="""
-- 30. Terminal vs customer fuel issued
SELECT Terminal, Customer, SUM(Quantity) AS Qty FROM B_TRANSACTIONS GROUP BY Terminal, Customer;
""")

vn.train(sql="""
-- 31. Vehicles refueled at FT-03
SELECT VehicleNumber FROM B_TRANSACTIONS WHERE Terminal = 'FT-03' GROUP BY VehicleNumber;
""")

vn.train(sql="""
-- 32. Peak refueling days
SELECT CAST(DateTime AS DATE) AS Day, SUM(Quantity) AS Total FROM B_TRANSACTIONS GROUP BY CAST(DateTime AS DATE) ORDER BY Total DESC;
""")

vn.train(sql="""
-- 33. Most recent stock balance
SELECT TOP 1 * FROM B_STOCKS ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 34. Refueling with quantity > 200
SELECT * FROM B_TRANSACTIONS WHERE Quantity > 200 ORDER BY Quantity DESC;
""")

vn.train(sql="""
-- 35. Monthly inflow summary
SELECT FORMAT(DateTime, 'yyyy-MM') AS Month, SUM(Inflow) AS TotalInflow FROM B_STOCKS GROUP BY FORMAT(DateTime, 'yyyy-MM');
""")

vn.train(sql="""
-- 36. Monthly dispensed summary
SELECT FORMAT(DateTime, 'yyyy-MM') AS Month, SUM(Dispensed) AS TotalOut FROM B_STOCKS GROUP BY FORMAT(DateTime, 'yyyy-MM');
""")

vn.train(sql="""
-- 37. Daily opening vs closing stock
SELECT DateTime, Opening, Closing FROM B_STOCKS;
""")

vn.train(sql="""
-- 38. Count of transactions with missing mileage
SELECT COUNT(*) FROM B_TRANSACTIONS WHERE Mileage IS NULL;
""")

vn.train(sql="""
-- 39. Count of transactions with AdditionalEntry filled
SELECT COUNT(*) FROM B_TRANSACTIONS WHERE AdditionalEntry IS NOT NULL;
""")

vn.train(sql="""
-- 40. Vehicle with most refueling events
SELECT TOP 1 VehicleNumber, COUNT(*) AS Count FROM B_TRANSACTIONS GROUP BY VehicleNumber ORDER BY Count DESC;
""")

vn.train(sql="""
-- 41. Terminal with least activity
SELECT TOP 1 Terminal, COUNT(*) AS Trans FROM B_TRANSACTIONS GROUP BY Terminal ORDER BY Trans;
""")

vn.train(sql="""
-- 42. Vehicles using card vs no card
SELECT 
    CASE WHEN Card IS NULL THEN 'No Card' ELSE 'With Card' END AS CardStatus,
    COUNT(*) AS Total
FROM B_TRANSACTIONS
GROUP BY CASE WHEN Card IS NULL THEN 'No Card' ELSE 'With Card' END;
""")

vn.train(sql="""
-- 43. Latest mileage record
SELECT TOP 1 VehicleNumber, Mileage FROM B_TRANSACTIONS WHERE Mileage IS NOT NULL ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 44. Last 7 days stock movement
SELECT TOP 7 * FROM B_STOCKS ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 45. Dispensed volume vs PT BAR
SELECT DateTime, Dispensed, [PT BAR] FROM B_STOCKS ORDER BY DateTime DESC;
""")

vn.train(sql="""
-- 46. Highest single transaction
SELECT TOP 1 * FROM B_TRANSACTIONS ORDER BY Quantity DESC;
""")

vn.train(sql="""
-- 47. Daily PT BAR usage trend
SELECT DateTime, [PT BAR] FROM B_STOCKS WHERE [PT BAR] > 0 ORDER BY DateTime;
""")

vn.train(sql="""
-- 48. Refueling events on weekend
SELECT * FROM B_TRANSACTIONS WHERE DATENAME(WEEKDAY, DateTime) IN ('Saturday', 'Sunday');
""")

vn.train(sql="""
-- 49. Summary of Quantity by day and terminal
SELECT CAST(DateTime AS DATE) AS Day, Terminal, SUM(Quantity) AS Qty FROM B_TRANSACTIONS GROUP BY CAST(DateTime AS DATE), Terminal;
""")

vn.train(sql="""
-- 50. Vehicle mileage range
SELECT VehicleNumber, MIN(Mileage) AS MinMileage, MAX(Mileage) AS MaxMileage FROM B_TRANSACTIONS WHERE Mileage IS NOT NULL GROUP BY VehicleNumber;
""")
# Out:
# Insert of existing embedding ID: d89f99d3-dc40-5947-972e-c3516b8d559b-ddl
# Add of existing embedding ID: d89f99d3-dc40-5947-972e-c3516b8d559b-ddl
# Insert of existing embedding ID: 6354aebb-c537-5e59-aaa9-3e987dd5b5e1-doc
# Add of existing embedding ID: 6354aebb-c537-5e59-aaa9-3e987dd5b5e1-doc
# Adding ddl:
# CREATE TABLE B_TRANSACTIONS (
#     ID_Transactions INT,
#     DateTime DATETIME,
#     Terminal NVARCHAR(108),
#     Card NVARCHAR(40),
#     Quantity FLOAT,
#     Customer NVARCHAR(100),
#     VehicleNumber NVARCHAR(30),
#     VehicleLicensePlate NVARCHAR(20),
#     Mileage INT,
#     AdditionalEntry NVARCHAR(20)
# );
#
# CREATE TABLE B_STOCKS (
#     DateTime DATETIME,
#     Opening FLOAT,
#     Inflow FLOAT,
#     [PT BAR] FLOAT,
#     Dispensed FLOAT,
#     Closing FLOAT
# );
#
# Adding documentation....
# Question generated with sql: Show the 10 latest transactions.
# Adding SQL...
# Question generated with sql: What is the total quantity processed per terminal for the current month?
# Adding SQL...
# Insert of existing embedding ID: 97c0e4ee-797c-5ec2-b3a8-6c6967377869-sql
# Add of existing embedding ID: 97c0e4ee-797c-5ec2-b3a8-6c6967377869-sql
# Question generated with sql: What is the total number of transactions for each customer in the current month?
# Adding SQL...
# Question generated with sql: What are the total quantities dispensed for each of the terminals FT-02, FT-03, and FT-04?
# Adding SQL...
# Question generated with sql: What is the total quantity of fuel issued to customers whose name contains 'PT BAR'?
# Adding SQL...
# Question generated with sql: What is the latest recorded mileage for each vehicle and the date it was recorded?
# Adding SQL...
# Question generated with sql: What are all the stock details for the current month?
# Adding SQL...
# Question generated with sql: What are the dates and quantities of all recorded fuel inflows?
# Adding SQL...
# Question generated with sql: Which dates had a high dispensed volume?
# Adding SQL...
# Insert of existing embedding ID: 453e4aa4-f436-5040-9e40-00fbebc1d701-sql
# Add of existing embedding ID: 453e4aa4-f436-5040-9e40-00fbebc1d701-sql
# Question generated with sql: What are the daily closing values for the current month?
# Adding SQL...
# Question generated with sql: What were the daily usage amounts for PT BAR?
# Adding SQL...
# Question generated with sql: How many times has each vehicle been refueled?
# Adding SQL...
# Question generated with sql: What is the daily total issued for the current month?
# Adding SQL...
# Question generated with sql: What is the total number of uses for each card?
# Adding SQL...
# Question generated with sql: Which transactions did not involve a card?
# Adding SQL...
# Question generated with sql: What is the total quantity processed per terminal per day for the current month?
# Adding SQL...
# Question generated with sql: What is the total refueling volume for each vehicle?
# Adding SQL...
# Question generated with sql: What are the top 5 terminals by volume?
# Adding SQL...
# Question generated with sql: How frequently is each terminal used?
# Adding SQL...
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[7], line 210
#     200 vn.train(sql="""
#     201 -- 18. Top 5 terminals by volume
#     202 SELECT TOP 5 Terminal, SUM(Quantity) AS Total FROM B_TRANSACTIONS GROUP BY Terminal ORDER BY Total DESC;
#     203 """)
#     205 vn.train(sql="""
#     206 -- 19. Terminal usage frequency
#     207 SELECT Terminal, COUNT(*) AS Frequency FROM B_TRANSACTIONS GROUP BY Terminal ORDER BY Frequency DESC;
#     208 """)
# --> 210 vn.train(sql="""
#     211 -- 20. Inflow vs dispensed comparison
#     212 SELECT DateTime, Inflow, Dispensed FROM B_STOCKS ORDER BY DateTime DESC;
#     213 """)
#     215 vn.train(sql="""
#     216 -- 21. Fuel received and opening stock
#     217 SELECT DateTime, Opening, Inflow FROM B_STOCKS ORDER BY DateTime;
#     218 """)
#     220 vn.train(sql="""
#     221 -- 22. Daily net change in stock
#     222 SELECT DateTime, (Opening + Inflow - Dispensed) AS NetStock FROM B_STOCKS;
#     223 """)
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\vanna\base\base.py:1834, in VannaBase.train(self, question, sql, ddl, documentation, plan)
#    1832 if sql:
#    1833     if question is None:
# -> 1834         question = self.generate_question(sql)
#    1835         print("Question generated with sql:", question, "\nAdding SQL...")
#    1836     return self.add_question_sql(question=question, sql=sql)
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\vanna\base\base.py:696, in VannaBase.generate_question(self, sql, **kwargs)
#     695 def generate_question(self, sql: str, **kwargs) -> str:
# --> 696     response = self.submit_prompt(
#     697         [
#     698             self.system_message(
#     699                 "The user will give you SQL and you will try to guess what the business question this query is answering. Return just the question without any additional explanation. Do not reference the table name in the question."
#     700             ),
#     701             self.user_message(sql),
#     702         ],
#     703         **kwargs,
#     704     )
#     706     return response
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\vanna\google\gemini_chat.py:68, in GoogleGeminiChat.submit_prompt(self, prompt, **kwargs)
#      67 def submit_prompt(self, prompt, **kwargs) -> str:
# ---> 68     response = self.chat_model.generate_content(
#      69         prompt,
#      70         generation_config={
#      71             "temperature": self.temperature,
#      72         },
#      73     )
#      74     return response.text
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\Fauzi.HEC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 10
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 58
# }
# ]

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#                                           id  \
# 0   062823c0-d462-5f61-87c7-ebcc7b4bdda9-sql
# 1   399065ec-0a12-59b1-b222-4db1fb173795-sql
# 2   d075bc35-0ae2-561a-8aa1-380627f9359a-sql
# 3   9efc3fec-0172-5c95-9614-0ff0357f64de-sql
# 4   c4e27017-3958-5f54-bbaf-4aaf31576a9a-sql
# 5   639c97b4-7a3c-5362-bc3c-cd80d52163c8-sql
# 6   16e73673-3cfa-57c1-861a-308132262677-sql
# 7   0d240a00-c470-5b74-b664-57cbd454582a-sql
# 8   d721b24d-45d3-514e-ac74-fbb5ac9a0e34-sql
# 9   40ae1da4-83d4-5cd0-951f-5628f6b5c37c-sql
# 10  97c0e4ee-797c-5ec2-b3a8-6c6967377869-sql
# 11  cc18fba0-722e-5e0f-8c91-3b5be1d9f8f9-sql
# 12  32615de4-42a9-545d-b342-01a7d33c243a-sql
# 13  83d39b2a-80d4-521a-9021-64096439a7b7-sql
# 14  255d4e19-3ae8-573f-85cc-c603858941d9-sql
# 15  eee51ac3-72c8-5cf2-8770-edafc5113970-sql
# 16  f42ffeac-765d-5de8-b74a-30a8c90e3e6d-sql
# 17  453e4aa4-f436-5040-9e40-00fbebc1d701-sql
# 18  0a7029b8-a498-5de6-b15b-d3920b1ff7ae-sql
# 19  6678ec80-37ee-511a-8457-cf36775b6d7b-sql
# 20  4d5d180c-925c-5f83-985c-4eb6b9aed341-sql
# 21  825491b8-7b7f-56f8-865d-75c343af88d2-sql
# 22  d1ad1266-c7d1-528c-9158-e63e5e6a59b6-sql
# 23  ad85ff10-df20-5b00-9686-f2ebbb06968e-sql
# 24  937611c5-31ef-5c7b-b1bc-a8c126810221-sql
# 25  ca8f4878-0dc1-5a66-963d-8071de518618-sql
# 26  9cd2145f-2f92-5f36-8d7b-1c441cf9ef26-sql
# 27  a1f064d3-f94b-527f-bcbd-ac2184421cf8-sql
# 28  9498b3ad-6b88-5b64-9ff4-74f3d2ff6df5-sql
# 29  67681016-d1f6-5ba1-bcd6-16363d1d5f9f-sql
# 30  1c94a479-82b1-56e3-9093-c48d8145f3b8-sql
# 31  a2eb9ac7-6bbc-56ec-b897-c807d95b254c-sql
# 32  4e0e07d8-2994-52b3-ac7a-a99edde5f6aa-sql
# 33  b9deaa58-71ad-55d6-a070-af9bc16763d6-sql
# 34  c304b211-3cd4-5365-a301-47d0d5fa9c38-sql
# 35  cf30306a-f016-5ec3-8bfa-38d5075feae8-sql
# 0   ae8465a2-0006-506d-afad-b914f3e96045-ddl
# 1   d89f99d3-dc40-5947-972e-c3516b8d559b-ddl
# 0   9f312a50-1b63-5af2-8649-e3e42b6a5c7b-doc
# 1   6354aebb-c537-5e59-aaa9-3e987dd5b5e1-doc
#
#                                              question  \
# 0   What are the details of the 10 most recent tra...
# 1   What is the total quantity of fuel dispensed a...
# 2   What is the daily total quantity of fuel dispe...
# 3   List all transactions that did not use an RFID...
# 4   What is the total number of refueling transact...
# 5   What are the details of all fuel received thro...
# 6   What are the details of fuel issuance transact...
# 7   how much fuel issued on vehicle and PT BAR on ...
# 8                    Show the latest 10 transactions.
# 9   What is the total quantity per terminal for th...
# 10  What is the total number of transactions for e...
# 11  How much was dispensed by each of the terminal...
# 12  What is the total quantity of fuel issued to P...
# 13  For each vehicle, what is its highest recorded...
# 14  What is the daily summary of inventory for the...
# 15  What are the dates and quantities for all fuel...
# 16  Which days had a dispensed volume greater than...
# 17  What are the daily closing values for the curr...
# 18                 What is the daily usage of PT BAR?
# 19                   Show the 10 latest transactions.
# 20  What is the total quantity processed per termi...
# 21  What are the total quantities dispensed for ea...
# 22  What is the total quantity of fuel issued to c...
# 23  What is the latest recorded mileage for each v...
# 24  What are all the stock details for the current...
# 25  What are the dates and quantities of all recor...
# 26           Which dates had a high dispensed volume?
# 27      What were the daily usage amounts for PT BAR?
# 28     How many times has each vehicle been refueled?
# 29  What is the daily total issued for the current...
# 30    What is the total number of uses for each card?
# 31         Which transactions did not involve a card?
# 32  What is the total quantity processed per termi...
# 33  What is the total refueling volume for each ve...
# 34            What are the top 5 terminals by volume?
# 35              How frequently is each terminal used?
# 0                                                None
# 1                                                None
# 0                                                None
# 1                                                None
#
#                                               content training_data_type
# 0   \n-- Show the 10 latest fuel transactions\nSEL...                sql
# 1   \n-- Total fuel dispensed per terminal\nSELECT...                sql
# 2   \n-- Daily total fuel usage per station\nSELEC...                sql
# 3   \n-- Transactions without RFID (identified man...                sql
# 4   \n-- Total refueling summary for a specific ve...                sql
# 5   \n-- Fuel received into tank (unloading activi...                sql
# 6   \n-- Fuel issued to vehicles and customers\nSE...                sql
# 7   SELECT\n    SUM(Quantity) AS TotalFuelIssued\n...                sql
# 8   \n-- 1. Show latest 10 transactions\nSELECT TO...                sql
# 9   \n-- 2. Total quantity per terminal for the cu...                sql
# 10  \n-- 3. Total transactions by customer for the...                sql
# 11  \n-- 4. Total dispensed from FT-02, FT-03, FT-...                sql
# 12  \n-- 5. Fuel issued to PT BAR\nSELECT SUM(Quan...                sql
# 13  \n-- 6. Mileage summary per vehicle\nSELECT \n...                sql
# 14  \n-- 7. Daily stock summary for the current mo...                sql
# 15  \n-- 8. Show days with fuel inflow or unloadin...                sql
# 16  \n-- 9. Show days with high dispensed volume\n...                sql
# 17  \n-- 10. Closing stock per day for the current...                sql
# 18  \n-- 11. PT BAR daily usage\nSELECT DateTime, ...                sql
# 19  \n-- 1. Show latest 10 transactions\nSELECT TO...                sql
# 20  \n-- 2. Total quantity per terminal for the cu...                sql
# 21  \n-- 4. Total dispensed from FT-02, FT-03, FT-...                sql
# 22  \n-- 5. Fuel issued to PT BAR\nSELECT SUM(Quan...                sql
# 23  \n-- 6. Mileage summary per vehicle\nSELECT \n...                sql
# 24  \n-- 7. Daily stock summary for the current mo...                sql
# 25  \n-- 8. Show days with fuel inflow or unloadin...                sql
# 26  \n-- 9. Show days with high dispensed volume\n...                sql
# 27  \n-- 11. PT BAR daily usage\nSELECT DateTime, ...                sql
# 28  \n-- 12. Vehicle refueling count\nSELECT \n   ...                sql
# 29  \n-- 13. Daily total issued\nSELECT \n    Date...                sql
# 30  \n-- 14. Card usage summary\nSELECT Card, COUN...                sql
# 31  \n-- 15. Show transactions without card\nSELEC...                sql
# 32  \n-- 16. Total quantity per terminal per day (...                sql
# 33  \n-- 17. Vehicle refueling volume\nSELECT Vehi...                sql
# 34  \n-- 18. Top 5 terminals by volume\nSELECT TOP...                sql
# 35  \n-- 19. Terminal usage frequency\nSELECT Term...                sql
# 0   \nCREATE TABLE B_TRANSCATIONS (\n    ID_Transa...                ddl
# 1   \nCREATE TABLE B_TRANSACTIONS (\n    ID_Transa...                ddl
# 0   \nThe B_TRANSACTIONS table records fuel refuel...      documentation
# 1   \nThe B_TRANSACTIONS table records fuel refuel...      documentation

# %%
# You can remove training data if there's obsolete/incorrect information.
# vn.remove_training_data(id='1-ddl')

# %% [markdown]
# ## Asking the AI
# Whenever you ask a new question, it will find the 10 most relevant pieces of training data and use it as part of the LLM prompt to generate the SQL.

# %%
vn.ask(question="How many transactions happened in July 2025?")
# Out:
# Number of requested results 10 is greater than number of elements in index 2, updating n_results = 2
# Number of requested results 10 is greater than number of elements in index 2, updating n_results = 2
# SQL Prompt: ["You are a T-SQL / Microsoft SQL Server expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Tables \n\nCREATE TABLE B_TRANSACTIONS (\n    ID_Transactions INT,\n    DateTime DATETIME,\n    Terminal NVARCHAR(108),\n    Card NVARCHAR(40),\n    Quantity FLOAT,\n    Customer NVARCHAR(100),\n    VehicleNumber NVARCHAR(30),\n    VehicleLicensePlate NVARCHAR(20),\n    Mileage INT,\n    AdditionalEntry NVARCHAR(20)\n);\n\nCREATE TABLE B_STOCKS (\n    DateTime DATETIME,\n    Opening FLOAT,\n    Inflow FLOAT,\n    [PT BAR] FLOAT,\n    Dispensed FLOAT,\n    Closing FLOAT\n);\n\n\n\nCREATE TABLE B_TRANSCATIONS (\n    ID_Transactions INT,\n    DateTime DATETIME,\n    Number INT,\n    Station NVARCHAR(30),\n    Terminal NVARCHAR(64),\n    Card NVARCHAR(40),\n    Quantity FLOAT,\n    QuantityUnit NVARCHAR(5),\n    Customer NVARCHAR(100),\n    VehicleNumber NVARCHAR(30),\n    VehicleLicensePlate NVARCHAR(20),\n    AdditionalEntry NVARCHAR(20),\n    Mileage INT\n)\n\n\n\n===Additional Context \n\n\nThe B_TRANSACTIONS table records fuel refueling activities by operational vehicles.\nID_Transactions: Unique identifier for each transaction.\nDateTime: Date and time of the fuel transaction.\nTerminal: Code of the fuel dispensing terminal/pump (e.g., FT-02, FM-01).\nCard: RFID card number used to identify the vehicle (optional).\nQuantity: Amount of fuel dispensed, in liters.\nCustomer: Name of the company or fuel consumer unit (e.g., PT BAR).\nVehicleNumber: Internal vehicle/unit code (e.g., GS-45-46).\nVehicleLicensePlate: Official license plate or vehicle tag.\nMileage: Odometer reading or hourmeter value at refueling time.\nAdditionalEntry: Backup field for vehicle info if RFID is not used.\n\nThe B_STOCKS table records daily fuel stock levels and movements.\nDateTime: Date and time of the stock record.\nOpening: Fuel stock at the start of the day.\nInflow: Total amount of fuel received (e.g., unloading from tanker).\nPT BAR: Fuel issued specifically to customer PT BAR.\nDispensed: Total fuel dispensed from terminals FT-02, FT-03, and FT-04 only.\nClosing: Remaining stock at the end of the day.\n\n\n\nThe B_TRANSACTIONS table records fuel refueling activities by operational vehicles.\nID_Transactions: Unique identifier for each transaction.\nDateTime: Date and time of the fuel transaction.\nNumber: Sequential transaction number on that day at the specific terminal.\nStation: Refueling site or location (e.g., BISM).\nTerminal: Code of the fuel dispensing terminal/pump, such as FT-02 or FT-03.\nCard: RFID card number used to identify the vehicle (if available).\nQuantity: Amount of fuel dispensed (in liters).\nQuantityUnit: Unit of the fuel quantity (commonly 'Ltrs').\nCustomer: Name of the company or fuel consumer unit.\nVehicleNumber: Vehicle identifier or unit code, such as 'CARD FT-04' or 'GS-25-26-27'.\nVehicleLicensePlate: License plate or vehicle identifier (can be similar to VehicleNumber).\nAdditionalEntry: Vehicle number or unit name when refueling is done without an RFID card.\nMileage: Vehicle mileage at the time of refueling (in kilometers or hourmeter), can be NULL.\n\n\n===Response Guidelines \n1. If the provided context is sufficient, please generate a valid SQL query without any explanations for the question. \n2. If the provided context is almost sufficient but requires knowledge of a specific string in a particular column, please generate an intermediate SQL query to find the distinct strings in that column. Prepend the query with a comment saying intermediate_sql \n3. If the provided context is insufficient, please explain why it can't be generated. \n4. Please use the most relevant table(s). \n5. If the question has been asked and answered before, please repeat the answer exactly as it was given before. \n6. Ensure that the output SQL is T-SQL / Microsoft SQL Server-compliant and ...
# 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 10
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# (None, None, None)

# %%
from vanna.flask import VannaFlaskApp
app = VannaFlaskApp(vn)
app.run(debug=False, use_reloader=False)
